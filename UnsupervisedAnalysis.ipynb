# %% [markdown]
# ### Unsupervised Analysis of Days of Week (Fremont Bike Rides - Seattle, Washington)
#
# Treating crossings each day as features to learn about the relationships between various days.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ### Get Data

# %%
from jupyterworkflow.data import get_fremont_data

data = get_fremont_data()

# %%
pivoted = data.pivot_table('Total', index=data.index.time, columns=data.index.date)
pivoted.plot(legend=False, alpha=0.01)

# %% [markdown]
# ### Principal Component Analysis

# %%
X = pivoted.fillna(0).T.values
X.shape
# Out:
# (2036, 24)

# %%
X2 = PCA(2, svd_solver='full').fit_transform(X)
X2.shape
# Out:
# (2036, 2)

# %%
plt.scatter(X2[:, 0], X2[:, 1])

# %% [markdown]
# we can see from above that we have two clusters of day types. It will be nice if we can automatically identify those clusters. One way to do this is to use Gaussian mixture model

# %% [markdown]
# ### Unsupervised Clustering

# %%
gmm = GaussianMixture(2).fit(X)
labels = gmm.predict(X)

# %%
# lets make it more colorful by adding cmap='rainbow'
plt.scatter(X2[:, 0], X2[:, 1], c=labels, cmap='rainbow')
plt.colorbar()

# %% [markdown]
# Lets explore this further by examining whats going on within these clusters.

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

pivoted.T[labels == 0].T.plot(legend=False, alpha=0.1, ax=ax[0]);
pivoted.T[labels == 1].T.plot(legend=False, alpha=0.1, ax=ax[1]);

ax[0].set_title('Purple Cluster')
ax[1].set_title('Red Cluster');

# %% [markdown]
# ### Comparing with Day of Week

# %%
dayof_week = pd.DatetimeIndex(pivoted.columns).dayofweek

# %%
plt.scatter(X2[:, 0], X2[:, 1], c=dayof_week, cmap='rainbow')
plt.colorbar()

# %% [markdown]
# ### Analyzing  Outliers
#
# The following points are weekdays with holiday-like pattern

# %%
dates = pd.DatetimeIndex(pivoted.columns)
dates[(labels == 1) & (dayof_week < 5)]
# Out:
# DatetimeIndex(['2012-11-22', '2012-11-23', '2012-12-24', '2012-12-25',
#                '2013-01-01', '2013-05-27', '2013-07-04', '2013-07-05',
#                '2013-09-02', '2013-11-28', '2013-11-29', '2013-12-20',
#                '2013-12-24', '2013-12-25', '2014-01-01', '2014-04-23',
#                '2014-05-26', '2014-07-04', '2014-09-01', '2014-11-27',
#                '2014-11-28', '2014-12-24', '2014-12-25', '2014-12-26',
#                '2015-01-01', '2015-05-25', '2015-07-03', '2015-09-07',
#                '2015-11-26', '2015-11-27', '2015-12-24', '2015-12-25',
#                '2016-01-01', '2016-05-30', '2016-07-04', '2016-09-05',
#                '2016-11-24', '2016-11-25', '2016-12-26', '2017-01-02',
#                '2017-02-06', '2017-05-29', '2017-07-04', '2017-09-04',
#                '2017-11-23', '2017-11-24', '2017-12-25', '2017-12-26',
#                '2018-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# What's up with February 6, 2017 in Seattle? [Snow Storm](https://www.seattletimes.com/seattle-news/weather/weather-service-predicts-3-to-6-inches-of-snow-in-seattle-area/)
